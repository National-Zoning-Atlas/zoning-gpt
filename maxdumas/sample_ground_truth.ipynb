# %%
import json
import re

import pandas as pd

# %%
existing_gt = pd.read_csv("../zoning/prompting/ground_truth.csv", index_col=[0, 2], na_values=["-"])

# %%
existing_gt
# Out:
#                            district_page  \
# town          district_abb
# bristol       R-40                    31
# cheshire      R-20A                   19
# east-haddam   C/B/IG                  24
# ellington     DMF                     10
# hebron        PRD                     10
# morris        CB                       9
# newington     R-12                  7, 8
# south-windsor AA-30               14, 15
# southington   CB                       8
# warren        North                   14
#
#                                                         district  \
# town          district_abb
# bristol       R-40                              Residential R-40
# cheshire      R-20A                            Residential R-20A
# east-haddam   C/B/IG        Commercial/Business/Light Industrial
# ellington     DMF                           Designed Multifamily
# hebron        PRD                Planned Residential Development
# morris        CB                                   Commercial CB
# newington     R-12                              Residential R-12
# south-windsor AA-30                    AA-30 Limited Residential
# southington   CB                                Central Business
# warren        North                                        North
#
#                            min_lot_size_page_gt min_unit_size_page_gt  \
# town          district_abb
# bristol       R-40                           48                   NaN
# cheshire      R-20A                          91                   NaN
# east-haddam   C/B/IG                      51/56                 51/56
# ellington     DMF                            24                    26
# hebron        PRD                            38                    39
# morris        CB                             44                    44
# newington     R-12                           48                   NaN
# south-windsor AA-30                          26                   NaN
# southington   CB                             71                   NaN
# warren        North                          16                   NaN
#
#                            min_lot_size_gt min_unit_size_gt
# town          district_abb
# bristol       R-40                   40000              NaN
# cheshire      R-20A                  20000              NaN
# east-haddam   C/B/IG                 21780             1000
# ellington     DMF           217800, 435600  700, 1000, 1200
# hebron        PRD                   348480              750
# morris        CB                     40000   1000, 700, 600
# newington     R-12                   12000              NaN
# south-windsor AA-30                  30000              NaN
# southington   CB                     30000              NaN
# warren        North                  87120              NaN

# %%
df = pd.read_excel("../data/zoning_atlas_data_2022.xlsx", "Town Data", index_col=[1, 2])

# %%
df = df.set_index(df.index.map(lambda i: (re.sub(r"[\s\-/]+", "-", i[0].strip().lower()), i[1].strip())))

# %%
df = df.drop(index=existing_gt.index)

# %%
ACRE_TO_SQ_FT = 4840 * 9

# %%
missing_min_lot_size_gt = df["1-Family Min. Lot (ACRES)"].isna()
min_lot_size_gt = pd.to_numeric(df["1-Family Min. Lot (ACRES)"], errors="coerce") * ACRE_TO_SQ_FT

# %%
missing_min_unit_size_gt = df["1-Family Min. Unit Size (SF)"].isna()
min_unit_size_gt = pd.to_numeric(df["1-Family Min. Unit Size (SF)"], errors="coerce")

# %% [markdown]
# The below code finds the rows of the dataframe that have 1-Family Min. Lot sizes
# that are special cases, in that they are not simple numeric values but include
# some sort of qualifier. We're interested in these cases because they will be
# more challenging to correctly determine. These samples will also be harder to
# evaluate correctness for, especially automatically, because any divergence in
# wording will generally be identified as incorrect.

# %%
df_special_case_lot_size = df[(~missing_min_lot_size_gt & min_lot_size_gt.isna()) | (~missing_min_unit_size_gt & min_unit_size_gt.isna())]
df_special_case_lot_size.sample(n=5)
# Out:
#                                   State  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                    CT
# canton        R-1                    CT
# columbia      LBR                    CT
# east-hartford B-1                    CT
# columbia      LAR                    CT
#
#                                                                   Full District Name  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                                                      Residential 2
# canton        R-1                                                    R-1 Residential
# columbia      LBR                  Columbia Lake-Overlay B on Residential Agricul...
# east-hartford B-1                                                         Business 1
# columbia      LAR                  Columbia Lake-Overlay A on Residential Agricul...
#
#                                     County                    NewCOG  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                  Hartford  Capitol Planning Region
# canton        R-1                  Hartford  Capitol Planning Region
# columbia      LBR                   Tolland  Capitol Planning Region
# east-hartford B-1                  Hartford  Capitol Planning Region
# columbia      LAR                   Tolland  Capitol Planning Region
#
#                                   Type of Zoning District   \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                    Primarily Residential
# canton        R-1                    Primarily Residential
# columbia      LBR                    Primarily Residential
# east-hartford B-1                   Mixed with Residential
# columbia      LAR                    Primarily Residential
#
#                                   Is it an Overlay District?  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                                         No
# canton        R-1                                         No
# columbia      LBR                                        Yes
# east-hartford B-1                                         No
# columbia      LAR                                        Yes
#
#                                               1-Family             2-Family  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                  Allowed/Conditional           Prohibited
# canton        R-1                  Allowed/Conditional  Allowed/Conditional
# columbia      LBR                  Allowed/Conditional           Prohibited
# east-hartford B-1                           Prohibited  Allowed/Conditional
# columbia      LAR                  Allowed/Conditional           Prohibited
#
#                                               3-Family       4+-Family  ...  \
# Jurisdiction  AbbreviatedDistrict                                       ...
# east-hartford R-2                           Prohibited      Prohibited  ...
# canton        R-1                           Prohibited      Prohibited  ...
# columbia      LBR                           Prohibited      Prohibited  ...
# east-hartford B-1                  Allowed/Conditional  Special Permit  ...
# columbia      LAR                           Prohibited      Prohibited  ...
#
#                                   4-Family Max. Height (# of feet)  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                                              NaN
# canton        R-1                                              NaN
# columbia      LBR                                              NaN
# east-hartford B-1                                              100
# columbia      LAR                                              NaN
#
#                                    4-Family Max. Lot Coverage IMPERVIOUS - BUILDINGS (%)  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                                                                NaN
# canton        R-1                                                                NaN
# columbia      LBR                                                                NaN
# east-hartford B-1                                                                 25
# columbia      LAR                                                                NaN
#
#                                    4-Family Max. Lot Coverage IMPERVIOUS - BUILDINGS & PAVEMENT (%)  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                                                                NaN
# canton        R-1                                                                NaN
# columbia      LBR                                                                NaN
# east-hartford B-1                                                                NaN
# columbia      LAR                                                                NaN
#
#                                    Notes  Tooltip Notes  Key Acres  \
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                    NaN            NaN  NaN   NaN
# canton        R-1                    NaN            NaN  NaN   NaN
# columbia      LBR                    NaN            NaN  NaN   NaN
# east-hartford B-1                    NaN            NaN  NaN   NaN
# columbia      LAR                    NaN            NaN  NaN   NaN
#
#                                   % Town Area  MunicipalKey  MunicipalAcres
# Jurisdiction  AbbreviatedDistrict
# east-hartford R-2                         NaN           NaN             NaN
# canton        R-1                         NaN           NaN             NaN
# columbia      LBR                         NaN           NaN             NaN
# east-hartford B-1                         NaN           NaN             NaN
# columbia      LAR                         NaN           NaN             NaN
#
# [5 rows x 126 columns]

# %%
n_samples = 233

# %%
n_special_case_samples = 33
n_normal_samples = n_samples - n_special_case_samples

# %%
special_case_samples = df_special_case_lot_size.sample(n=n_special_case_samples)

# %% [markdown]
# For our normal samples, we want to make sure that they span the rest of the zoning documents.

# %%
# TODO: We have zoning codes for these towns but we never processed them! We should do that!
exempt_names = set(("bethlehem", "eastford", "hartford", "north-stonington"))

with open("../data/names_all_towns.json") as f:
    names_all_towns = set(json.load(f)) - exempt_names

# %%
len(names_all_towns)
# Out:
# 176

# %%
special_case_samples.reset_index().Jurisdiction.unique()
# Out:
# array(['colchester', 'stamford', 'haddam', 'suffield', 'canton',
#        'clinton', 'lebanon', 'griswold-jewett-city', 'andover',
#        'east-hartford', 'north-canaan', 'columbia', 'morris', 'thompson',
#        'new-britain', 'marlborough', 'hamden', 'westbrook', 'durham',
#        'north-haven', 'sprague'], dtype=object)

# %%
remaining_towns = names_all_towns - (set(existing_gt.index.levels[0]) | set(special_case_samples.reset_index().Jurisdiction.unique()))

# %%
len(remaining_towns)
# Out:
# 146

# %%
samples = [df.drop(index=special_case_samples.index).loc[(town, slice(None)), :].sample() for town in remaining_towns]
sample_df = pd.concat((special_case_samples, *samples))
remaining_towns = names_all_towns - (set(existing_gt.index.levels[0]) | set(sample_df.reset_index().Jurisdiction.unique()))

# %%
sample_df
# Out:
#                                  State                Full District Name  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                    CT                      Suburban Use
# stamford     R-D                    CT               Designed Residence
# haddam       R-1                    CT                   Residential R-1
# suffield     R-90                   CT   R-90 Single Family Residential
# canton       R-3                    CT                   R-3 Residential
# ...                                ...                               ...
# west-haven   PVD                    CT                   Planned Village
# willington   DC                     CT               Designed Commercial
# east-granby  PRD                    CT               Planned Residential
# redding      SB                     CT                  Service Business
# vernon       HD-RC                  CT  HIstoric-Residential Commercial
#
#                                      County   \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                  New London
# stamford     R-D                  Fairfield
# haddam       R-1                   Middlesex
# suffield     R-90                   Hartford
# canton       R-3                    Hartford
# ...                                      ...
# west-haven   PVD                   New Haven
# willington   DC                      Tolland
# east-granby  PRD                    Hartford
# redding      SB                   Fairfield
# vernon       HD-RC                   Tolland
#
#                                                                           NewCOG  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                        Southeastern Connecticut Planning Region
# stamford     R-D                             Western Connecticut Planning Region
# haddam       R-1                  Lower Connecticut River Valley Planning Region
# suffield     R-90                                        Capitol Planning Region
# canton       R-3                                         Capitol Planning Region
# ...                                                                          ...
# west-haven   PVD                       South Central Connecticut Planning Region
# willington   DC                                          Capitol Planning Region
# east-granby  PRD                                         Capitol Planning Region
# redding      SB                              Western Connecticut Planning Region
# vernon       HD-RC                                       Capitol Planning Region
#
#                                  Type of Zoning District   \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                   Mixed with Residential
# stamford     R-D                    Primarily Residential
# haddam       R-1                    Primarily Residential
# suffield     R-90                   Primarily Residential
# canton       R-3                    Primarily Residential
# ...                                                   ...
# west-haven   PVD                   Mixed with Residential
# willington   DC                            No Residential
# east-granby  PRD                    Primarily Residential
# redding      SB                    Mixed with Residential
# vernon       HD-RC                 Mixed with Residential
#
#                                  Is it an Overlay District?  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                                         No
# stamford     R-D                                        Yes
# haddam       R-1                                         No
# suffield     R-90                                        No
# canton       R-3                                         No
# ...                                                     ...
# west-haven   PVD                                        Yes
# willington   DC                                          No
# east-granby  PRD                                         No
# redding      SB                                          No
# vernon       HD-RC                                       No
#
#                                              1-Family             2-Family  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                  Allowed/Conditional  Allowed/Conditional
# stamford     R-D                       Special Permit       Special Permit
# haddam       R-1                  Allowed/Conditional  Allowed/Conditional
# suffield     R-90                 Allowed/Conditional       Special Permit
# canton       R-3                  Allowed/Conditional  Allowed/Conditional
# ...                                               ...                  ...
# west-haven   PVD                  Allowed/Conditional  Allowed/Conditional
# willington   DC                            Prohibited           Prohibited
# east-granby  PRD                  Allowed/Conditional           Prohibited
# redding      SB                   Allowed/Conditional           Prohibited
# vernon       HD-RC                Allowed/Conditional  Allowed/Conditional
#
#                                              3-Family            4+-Family  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                       Special Permit       Special Permit
# stamford     R-D                       Special Permit           Prohibited
# haddam       R-1                           Prohibited           Prohibited
# suffield     R-90                          Prohibited           Prohibited
# canton       R-3                           Prohibited           Prohibited
# ...                                               ...                  ...
# west-haven   PVD                  Allowed/Conditional  Allowed/Conditional
# willington   DC                            Prohibited           Prohibited
# east-granby  PRD                           Prohibited           Prohibited
# redding      SB                            Prohibited           Prohibited
# vernon       HD-RC                     Special Permit       Special Permit
#
#                                   ... 4-Family Max. Height (# of feet)  \
# Jurisdiction AbbreviatedDistrict  ...
# colchester   SZD                  ...                               35
# stamford     R-D                  ...                              NaN
# haddam       R-1                  ...                              NaN
# suffield     R-90                 ...                              NaN
# canton       R-3                  ...                              NaN
# ...                               ...                              ...
# west-haven   PVD                  ...                            45.75
# willington   DC                   ...                              NaN
# east-granby  PRD                  ...                              NaN
# redding      SB                   ...                              NaN
# vernon       HD-RC                ...                               35
#
#                                   4-Family Max. Lot Coverage IMPERVIOUS - BUILDINGS (%)  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                                                                NaN
# stamford     R-D                                                                NaN
# haddam       R-1                                                                NaN
# suffield     R-90                                                               NaN
# canton       R-3                                                                NaN
# ...                                                                             ...
# west-haven   PVD                                                                 50
# willington   DC                                                                 NaN
# east-granby  PRD                                                                NaN
# redding      SB                                                                 NaN
# vernon       HD-RC                                                              NaN
#
#                                   4-Family Max. Lot Coverage IMPERVIOUS - BUILDINGS & PAVEMENT (%)  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                                                                NaN
# stamford     R-D                                                                NaN
# haddam       R-1                                                                NaN
# suffield     R-90                                                               NaN
# canton       R-3                                                                NaN
# ...                                                                             ...
# west-haven   PVD                                                                 70
# willington   DC                                                                 NaN
# east-granby  PRD                                                                NaN
# redding      SB                                                                 NaN
# vernon       HD-RC                                                               60
#
#                                                                               Notes  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                                                                NaN
# stamford     R-D                                                                NaN
# haddam       R-1                                                                NaN
# suffield     R-90                                                               NaN
# canton       R-3                                                                NaN
# ...                                                                             ...
# west-haven   PVD                                                                NaN
# willington   DC                                                                 NaN
# east-granby  PRD                                                                NaN
# redding      SB                   ADU expires 36 months from receiving certifica...
# vernon       HD-RC                                                              NaN
#
#                                                               Tooltip Notes  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                                                        NaN
# stamford     R-D                                                        NaN
# haddam       R-1                                                        NaN
# suffield     R-90                                                       NaN
# canton       R-3                                                        NaN
# ...                                                                     ...
# west-haven   PVD                                                        NaN
# willington   DC                                                         NaN
# east-granby  PRD                                                        NaN
# redding      SB                   ADU permit must be renewed every 3 years.
# vernon       HD-RC                                                      NaN
#
#                                               Key       Acres % Town Area  \
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                              NaN         NaN         NaN
# stamford     R-D                              NaN         NaN         NaN
# haddam       R-1                              NaN         NaN         NaN
# suffield     R-90                             NaN         NaN         NaN
# canton       R-3                              NaN         NaN         NaN
# ...                                           ...         ...         ...
# west-haven   PVD                  West Haven--PVD         NaN         NaN
# willington   DC                    Willington--DC  226.409666    1.062677
# east-granby  PRD                              NaN         NaN         NaN
# redding      SB                               NaN         NaN         NaN
# vernon       HD-RC                            NaN         NaN         NaN
#
#                                      MunicipalKey  MunicipalAcres
# Jurisdiction AbbreviatedDistrict
# colchester   SZD                              NaN             NaN
# stamford     R-D                              NaN             NaN
# haddam       R-1                              NaN             NaN
# suffield     R-90                             NaN             NaN
# canton       R-3                              NaN             NaN
# ...                                           ...             ...
# west-haven   PVD                  West Haven--PVD             NaN
# willington   DC                    Willington--DC           224.6
# east-granby  PRD                              NaN             NaN
# redding      SB                               NaN             NaN
# vernon       HD-RC                            NaN             NaN
#
# [179 rows x 126 columns]

# %% [markdown]
# Now that we've got at least one sample from every town, keep sampling randomly the remaining number of samples.

# %%
sample_df = pd.concat((sample_df, df.sample(n=n_samples - len(existing_gt) - len(sample_df))))

# %%
sample_df = (sample_df[["Full District Name", "1-Family Min. Lot (ACRES)", "1-Family Min. Unit Size (SF)"]]
    .rename(columns={
        "Full District Name": "district",
        "1-Family Min. Lot (ACRES)": "min_lot_size_acres_gt_raw",
        "1-Family Min. Unit Size (SF)": "min_unit_size_sf_gt_raw"
    }).rename_axis(index={
        "Jurisdiction": "town",
        "AbbreviatedDistrict": "district_abb"
    }).assign(
        min_lot_size_gt=min_lot_size_gt,
        district_page=pd.NA,
        min_lot_size_page_gt=pd.NA,
        min_unit_size_gt=min_unit_size_gt,
        min_unit_size_page_gt=pd.NA,
    )
)

# %%
sample_df
# Out:
#                                                                 district  \
# town         district_abb
# colchester   SZD                                            Suburban Use
# stamford     R-D                                     Designed Residence
# haddam       R-1                                         Residential R-1
# suffield     R-90                        R-90 Single Family Residential
# canton       R-3                                         R-3 Residential
# ...                                                                  ...
# redding      R-1/2                                  Suburban Residential
# berlin       VDO                                         Village Overlay
# wallingford  RU-40                                  Rural Residential-40
# stafford     B                                       General Residence B
# new-hartford Aquifer Protection Overlay       Aquifer Protection Overlay
#
#                                                                  min_lot_size_acres_gt_raw  \
# town         district_abb
# colchester   SZD                                                                  0.688705
# stamford     R-D                         25 in RA-3, 15 in RA-2, 10 in RA-1, 8 in R-20 ...
# haddam       R-1                                                                         1
# suffield     R-90                                                                 2.066116
# canton       R-3                                                       2 (front); 3 (rear)
# ...                                                                                    ...
# redding      R-1/2                                                                     0.5
# berlin       VDO                                                                       NaN
# wallingford  RU-40                                                                    1.84
# stafford     B                                                                        0.92
# new-hartford Aquifer Protection Overlay                                                NaN
#
#                                                                    min_unit_size_sf_gt_raw  \
# town         district_abb
# colchester   SZD                         1000 (one-story); 1200 (1.5 story); 1400 (two-...
# stamford     R-D                                                                       NaN
# haddam       R-1                                              500/studio, 700/1BR, 900/2BR
# suffield     R-90                                           1000 (one-bed); 1250 (two-bed)
# canton       R-3                                                                       NaN
# ...                                                                                    ...
# redding      R-1/2                                                                     NaN
# berlin       VDO                                                                       NaN
# wallingford  RU-40                                                                     NaN
# stafford     B                                                                        1000
# new-hartford Aquifer Protection Overlay                                                NaN
#
#                                          min_lot_size_gt district_page  \
# town         district_abb
# colchester   SZD                                 30000.0           NaN
# stamford     R-D                                     NaN           NaN
# haddam       R-1                                 43560.0           NaN
# suffield     R-90                                90000.0           NaN
# canton       R-3                                     NaN           NaN
# ...                                                  ...           ...
# redding      R-1/2                               21780.0           NaN
# berlin       VDO                                     NaN           NaN
# wallingford  RU-40                               80150.4           NaN
# stafford     B                                   40075.2           NaN
# new-hartford Aquifer Protection Overlay              NaN           NaN
#
#                                         min_lot_size_page_gt  \
# town         district_abb
# colchester   SZD                                         NaN
# stamford     R-D                                         NaN
# haddam       R-1                                         NaN
# suffield     R-90                                        NaN
# canton       R-3                                         NaN
# ...                                                      ...
# redding      R-1/2                                       NaN
# berlin       VDO                                         NaN
# wallingford  RU-40                                       NaN
# stafford     B                                           NaN
# new-hartford Aquifer Protection Overlay                  NaN
#
#                                          min_unit_size_gt  \
# town         district_abb
# colchester   SZD                                      NaN
# stamford     R-D                                      NaN
# haddam       R-1                                      NaN
# suffield     R-90                                     NaN
# canton       R-3                                      NaN
# ...                                                   ...
# redding      R-1/2                                    NaN
# berlin       VDO                                      NaN
# wallingford  RU-40                                    NaN
# stafford     B                                     1000.0
# new-hartford Aquifer Protection Overlay               NaN
#
#                                         min_unit_size_page_gt
# town         district_abb
# colchester   SZD                                          NaN
# stamford     R-D                                          NaN
# haddam       R-1                                          NaN
# suffield     R-90                                         NaN
# canton       R-3                                          NaN
# ...                                                       ...
# redding      R-1/2                                        NaN
# berlin       VDO                                          NaN
# wallingford  RU-40                                        NaN
# stafford     B                                            NaN
# new-hartford Aquifer Protection Overlay                   NaN
#
# [223 rows x 8 columns]

# %%
final_sample_df = pd.concat((sample_df, existing_gt))

# %%
final_sample_df.to_csv("../data/ground_truth.csv")
